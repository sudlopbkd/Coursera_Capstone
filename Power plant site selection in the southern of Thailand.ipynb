# %% [markdown]
# #### Capstone Project - The Battle of Neighborhoods

# %% [markdown]
# ##### **Disclaimer: Informations ans results from this work are only simulated for the capstone project and do not reflect any actual situation in the area**

# %% [markdown]
# # Pre-feasibility study: Power plant location selection in the southern of Thailand

# %% [markdown]
# ## Table of contents
# * [Introduction: Business Problem](#introduction)
# * [Data](#data)
# * [Methodology](#methodology)
# * [Analysis](#analysis)
# * [Results and Discussion](#results)
# * [Conclusion](#conclusion)

# %% [markdown]
# ## Introduction: Business Problem <a name="introduction"></a>

# %% [markdown]
# According to the latest Power Development Plan, the new power plant must be constructed to meet the increasing electricity demand locating in the southern of Thailand. The plan has been concluded in the previous stage of studies that the type of newly built power plant will be combine-cycle power plant using Natural gas and will be located within area of **Songkhla and Phattalung province**.
# The operation of fossil-fired power plant cause both environmental and social effects. Therefore it is the first priority in this stage to locate plant with minimum effects towards the nearby social area.

# %% [markdown]
# **The aims of this study is to locate the optimal location of power plant that minimize the impact towards nearby locals.**

# %% [markdown]
# ## Data <a name="data"></a>

# %% [markdown]
# This study uses the following data:
# * Latitude and Longitude of each sub-district in the area from [[1]]
#
# * Number and types of venue in the area from Foursqure.
#
# [1]:  https://github.com/codesanook/thailand-administrative-division-province-district-subdistrict-sql?fbclid=IwAR02dmKnvJ9cEx1UXHucR60DSP8vbVukXQEdgg7R4nc-iQ5FbhTuyqVfeCg

# %% [markdown]
# ## Methodology <a name="methodology"></a>

# %% [markdown]
# The methodolgies are as follow:
# * Collection the sub-district latitude longitude coordinate from [1]
# * Plot locations by Folium
# * Collection the venue in the area from Foursqure
# * Cluster the type of venues by K-means cluster
# * Calculate the distance by latitude longitude coordinate

# %% [markdown]
# ## Analysis <a name="analysis"></a>

# %% [markdown]
# ### 1. Collects the sub-district latitude longitude coordinate

# %%
#import libraries
import requests
import pandas as pd
import csv
import urllib.request
from bs4 import BeautifulSoup
import json # library to handle JSON files

#!conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

# %%
s_province = pd.read_csv("Southern of Thailand 2.csv")
s_province[:12]
# Out:
#      TA_ID            TAMBON  AM_ID           AMPHOE  Province  Latitude  \
# 0   900803        Choeng Sae   9008       Krasae Sin  Songkhla     7.561
# 1   901107  Khlong U Ta Phao   9011          Hat Yai  Songkhla     7.045
# 2   900703           Takhria   9007            Ranot  Songkhla     7.789
# 3   900705           Ban Mai   9007            Ranot  Songkhla     7.780
# 4   900106             Ko Yo   9001  Muaeng Songkhla  Songkhla     7.163
# 5   900204          Di Luang   9002     Sathing Phra  Songkhla     7.580
# 6   900804        Krasae Sin   9008       Krasae Sin  Songkhla     7.609
# 7   900203        Sanam Chai   9002     Sathing Phra  Songkhla     7.547
# 8   901509          Hua Khao   9015     Singhanakhon  Songkhla     7.214
# 9   900209          Wat Chan   9002     Sathing Phra  Songkhla     7.382
# 10  900202       Kradang Nga   9002     Sathing Phra  Songkhla     7.509
# 11  900211             Bodan   9002     Sathing Phra  Songkhla     7.435
#
#     Longitude
# 0     100.356
# 1     100.446
# 2     100.269
# 3     100.288
# 4     100.542
# 5     100.406
# 6     100.307
# 7     100.417
# 8     100.567
# 9     100.461
# 10    100.427
# 11    100.447

# %% [markdown]
# ### 2. Plot sub-districts on map

# %%
address = 'Songkhla'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Possible sites are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Possible sites are 6.8790221, 100.5498542.

# %%
map_th = folium.Map(location = [latitude, longitude], zoom_start = 9)
for lat, lng, tambon in zip(s_province['Latitude'], s_province['Longitude'], s_province['TAMBON']):
    label = '{}'.format(tambon)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_th)  
    
map_th
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### 3. Acquire venue in the area via FOURSQUARE

# %%
CLIENT_ID = 'NPIEW4LSZMNYKEBYVXEWY11Z5TYMO3YTCCJOV5LL0RQKDTGH' # your Foursquare ID
CLIENT_SECRET = 'D1HCA04DHJNRQ5BQWWDC5S4X5JFXEDDMTWBWRF3Y4GBZCZYV' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID:
# Don Pradu
# Laem Tanot
# Pantae
# Han Thao
# Khuan Kha Nun
# Chamuang
# Lam Sin
# Khok Sak
# Khao Ya
# Chai Buri
# Kong Ra
# Wang Mai
# Khlong Yai
# Chum Phon
# Khlong Sai Khao
# Pa Bon
# Khao Chaison
# Han Pho
# Khok Muang
# Han Pho
# Ko Nangkham
# Na Pakho
# Khao Pu
# Thung Nari
# Khok Sai
# Tapaen
# Phanang Tung
# Fa La Mi
# Ko Tao
# Thale Noi
# Ban Na
# Lam Pam
# Khlong Cha Loem
# Ko Mak
# Tanot
# Nong Thong

# %%
#th_venues.to_csv('songkhla.csv', index=False)

# %%
th_venues.groupby('Neighborhood').count()
# Out:
#                   Neighborhood Latitude  Neighborhood Longitude  Venue  \
# Neighborhood
# Bo Yang                              12                      12     12
# Cha Thing Phra                        2                       2      2
# Chalung                               1                       1      1
# Ching Kho                             1                       1      1
# Di Luang                              1                       1      1
# Han Thao                              1                       1      1
# Hat Yai                              69                      69     69
# Hua Khao                              1                       1      1
# Khao Chiak                            1                       1      1
# Khao Rupchang                         4                       4      4
# Khlong Hae                            4                       4      4
# Khlong U Ta Phao                      1                       1      1
# Kho Hong                              4                       4      4
# Khu Ha Sa Wan                         4                       4      4
# Khu Tao                               2                       2      2
# Khuan Ru                              1                       1      1
# Khun Tat Wai                          1                       1      1
# Ko Yo                                 1                       1      1
# Muang Ngam                            4                       4      4
# Na Mom                                1                       1      1
# Na Not                                1                       1      1
# Nakhayat                              2                       2      2
# Nam Noi                               1                       1      1
# Pak Trae                              4                       4      4
# Phang La                              1                       1      1
# Prang Mu                              1                       1      1
# Ra Wa                                 1                       1      1
# Sa Kom                                1                       1      1
# Sadao                                 4                       4      4
# Sanam Chai                            1                       1      1
# Tha Chang                             2                       2      2
# Tha Hin                               2                       2      2
# Tha Kham                              2                       2      2
# Tha Mi Ram                            1                       1      1
# Tham Nop                              1                       1      1
# Thung Khamin                          1                       1      1
# Wat Khanun                            1                       1      1
#
#                   Venue Latitude  Venue Longitude  Venue Category
# Neighborhood
# Bo Yang                       12               12              12
# Cha Thing Phra                 2                2               2
# Chalung                        1                1               1
# Ching Kho                      1                1               1
# Di Luang                       1                1               1
# Han Thao                       1                1               1
# Hat Yai                       69               69              69
# Hua Khao                       1                1               1
# Khao Chiak                     1                1               1
# Khao Rupchang                  4                4               4
# Khlong Hae                     4                4               4
# Khlong U Ta Phao               1                1               1
# Kho Hong                       4                4               4
# Khu Ha Sa Wan                  4                4               4
# Khu Tao                        2                2               2
# Khuan Ru                       1                1               1
# Khun Tat Wai                   1                1               1
# Ko Yo                          1                1               1
# Muang Ngam                     4                4               4
# Na Mom                         1                1               1
# Na Not                         1                1               1
# Nakhayat                       2                2               2
# Nam Noi                        1                1               1
# Pak Trae                       4                4               4
# Phang La                       1                1               1
# Prang Mu                       1                1               1
# Ra Wa                          1                1               1
# Sa Kom                         1                1               1
# Sadao                          4                4               4
# Sanam Chai                     1                1               1
# Tha Chang                      2                2               2
# Tha Hin                        2                2               2
# Tha Kham                       2                2               2
# Tha Mi Ram                     1                1               1
# Tham Nop                       1                1               1
# Thung Khamin                   1                1               1
# Wat Khanun                     1                1               1

# %% [markdown]
# ### 4. Categorize type of venues in the area

# %%
th_onehot = pd.get_dummies(th_venues[['Venue Category']], prefix="", prefix_sep="")
#TN_onehot.drop(['Neighborhood'], axis = 1, inplace = True)
th_onehot['Neighborhood'] = th_venues['Neighborhood']

fixed_columns = [th_onehot.columns[-1]]+ list(th_onehot.columns[:-1])
th_onehot = th_onehot[fixed_columns]

th_grouped = th_onehot.groupby('Neighborhood').mean().reset_index()

th_grouped
# Out:
#         Neighborhood  Airport Service  Arcade  Arts & Crafts Store  \
# 0            Bo Yang              0.0     0.0                  0.0
# 1     Cha Thing Phra              0.0     0.0                  0.5
# 2            Chalung              0.0     0.0                  0.0
# 3          Ching Kho              0.0     0.0                  0.0
# 4           Di Luang              0.0     0.0                  0.0
# 5           Han Thao              0.0     0.0                  0.0
# 6            Hat Yai              0.0     0.0                  0.0
# 7           Hua Khao              0.0     0.0                  0.0
# 8         Khao Chiak              1.0     0.0                  0.0
# 9      Khao Rupchang              0.0     0.0                  0.0
# 10        Khlong Hae              0.0     0.0                  0.0
# 11  Khlong U Ta Phao              0.0     0.0                  0.0
# 12          Kho Hong              0.0     0.0                  0.0
# 13     Khu Ha Sa Wan              0.0     0.0                  0.0
# 14           Khu Tao              0.0     0.0                  0.0
# 15          Khuan Ru              0.0     0.0                  0.0
# 16      Khun Tat Wai              0.0     0.0                  0.0
# 17             Ko Yo              0.0     0.0                  0.0
# 18        Muang Ngam              0.0     0.0                  0.0
# 19            Na Mom              0.0     0.0                  0.0
# 20            Na Not              0.0     0.0                  0.0
# 21          Nakhayat              0.0     0.0                  0.0
# 22           Nam Noi              0.0     0.0                  0.0
# 23          Pak Trae              0.0     0.0                  0.0
# 24          Phang La              0.0     0.0                  0.0
# 25          Prang Mu              0.0     0.0                  0.0
# 26             Ra Wa              0.0     0.0                  0.0
# 27            Sa Kom              0.0     0.0                  0.0
# 28             Sadao              0.0     0.0                  0.0
# 29        Sanam Chai              0.0     0.0                  0.0
# 30         Tha Chang              0.0     0.0                  0.0
# 31           Tha Hin              0.0     0.5                  0.0
# 32          Tha Kham              0.0     0.0                  0.0
# 33        Tha Mi Ram              0.0     0.0                  0.0
# 34          Tham Nop              0.0     0.0                  0.0
# 35      Thung Khamin              0.0     0.0                  0.0
# 36        Wat Khanun              0.0     0.0                  0.0
#
#     Asian Restaurant  Bakery  Basketball Court  Beach  Bookstore  \
# 0           0.000000    0.00          0.000000    0.0   0.000000
# 1           0.000000    0.00          0.000000    0.0   0.000000
# 2           0.000000    0.00          0.000000    0.0   0.000000
# 3           0.000000    0.00          0.000000    0.0   0.000000
# 4           0.000000    0.00          0.000000    0.0   0.000000
# 5           0.000000    0.00          0.000000    0.0   0.000000
# 6           0.014493    0.00          0.014493    0.0   0.014493
# 7           0.000000    0.00          0.000000    0.0   0.000000
# 8           0.000000    0.00          0.000000    0.0   0.000000
# 9           0.000000    0.00          0.000000    0.0   0.000000
# 10          0.000000    0.25          0.000000    0.0   0.000000
# 11          0.000000    0.00          0.000000    0.0   0.000000
# 12          0.000000    0.00          0.000000    0.0   0.000000
# 13          0.000000    0.00          0.000000    0.0   0.000000
# 14          0.000000    0.00          0.000000    0.0   0.000000
# 15          1.000000    0.00          0.000000    0.0   0.000000
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = th_grouped['Neighborhood']

for ind in np.arange(th_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(th_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted[0:40]
# Out:
#         Neighborhood      1st Most Common Venue  \
# 0            Bo Yang               Noodle House
# 1     Cha Thing Phra                Coffee Shop
# 2            Chalung                      Trail
# 3          Ching Kho            Thai Restaurant
# 4           Di Luang         Seafood Restaurant
# 5           Han Thao                Coffee Shop
# 6            Hat Yai                      Hotel
# 7           Hua Khao                   Mountain
# 8         Khao Chiak            Airport Service
# 9      Khao Rupchang                     Resort
# 10        Khlong Hae               Intersection
# 11  Khlong U Ta Phao  Middle Eastern Restaurant
# 12          Kho Hong          Convenience Store
# 13     Khu Ha Sa Wan               Noodle House
# 14           Khu Tao                  Racetrack
# 15          Khuan Ru           Asian Restaurant
# 16      Khun Tat Wai            Thai Restaurant
# 17             Ko Yo         Seafood Restaurant
# 18        Muang Ngam               Intersection
# 19            Na Mom                     Resort
# 20            Na Not                      Plaza
# 21          Nakhayat                       Food
# 22           Nam Noi              Metro Station
# 23          Pak Trae                   Sake Bar
# 24          Phang La                    Stables
# 25          Prang Mu                Pizza Place
# 26             Ra Wa                   Bus Stop
# 27            Sa Kom                      Beach
# 28             Sadao                Coffee Shop
# 29        Sanam Chai            Thai Restaurant
# 30         Tha Chang                       Food
# 31           Tha Hin            Nature Preserve
# 32          Tha Kham          Convenience Store
# 33        Tha Mi Ram           Department Store
# 34          Tham Nop          Electronics Store
# 35      Thung Khamin         Dim Sum Restaurant
# 36        Wat Khanun          Convenience Store
#
#             2nd Most Common Venue          3rd Most Common Venue  \
# 0                     Snack Place            Japanese Restaurant
# 1             Arts & Crafts Store  Vegetarian / Vegan Restaurant
# 2   Vegetarian / Vegan Restaurant                    Flower Shop
# 3   Vegetarian / Vegan Restaurant                    Flower Shop
# 4   Vegetarian / Vegan Restaurant                    Flea Market
# 5   Vegetarian / Vegan Restaurant               Department Store
# 6                    Noodle House              Convenience Store
# 7   Vegetarian / Vegan Restaurant               Department Store
# 8             Japanese Restaurant                 Ice Cream Shop
# 9                            Lake                    Observatory
# 10                    Coffee Shop                         Market
# 11  Vegetarian / Vegan Restaurant               Department Store
# 12                    Coffee Shop                           Pool
# 13                  Train Station                         Market
# 14               Toy / Game Store                    Flea Market
# 15  Vegetarian / Vegan Restaurant               Department Store
# 16  Vegetarian / Vegan Restaurant                    Flower Shop
# 17  Vegetarian / Vegan Restaurant                    Flea Market
# 18              Food & Drink Shop                  Shopping Mall
# 19              Convenience Store                 Ice Cream Shop
# 20  Vegetarian / Vegan Restaurant               Department Store
# 21                 Breakfast Spot  Vegetarian / Vegan Restaurant
# 22  Vegetarian / Vegan Restaurant               Department Store
# 23                       Tea Room                         Bakery
# 24  Vegetarian / Vegan Restaurant                    Flower Shop
# 25  Vegetarian / Vegan Restaurant               Department Store
# 26  Vegetarian / Vegan Restaurant               Department Store
# 27  Vegetarian / Vegan Restaurant               Department Store
# 28               Asian Restaurant             Chinese Restaurant
# 29  Vegetarian / Vegan Restaurant                    Flower Shop
# 30                    Flower Shop  Vegetarian / Vegan Restaurant
# 31                         Arcade  Vegetarian / Vegan Restaurant
# 32               Asian Restaurant               Department Store
# 33  Vegetarian / Vegan Restaurant            Japanese Restaurant
# 34  Vegetarian / Vegan Restaurant            Japanese Restaurant
# 35  Vegetarian / Vegan Restaurant            Japanese Restaurant
# 36            Japanese Restaurant                 Ice Cream Shop
#
#    4th Most Common Venue          5th Most Common Venue 6th Most Common Venue  \
# 0                  Hotel                     Restaurant                 Diner
# 1            Flower Shop             Dim Sum Restaurant                 Diner
# 2           Dessert Shop             Dim Sum Restaurant                 Diner
# 3           Dessert Shop             Dim Sum Restaurant                 Diner
# 4           Dessert Shop             Dim Sum Restaurant                 Diner
# 5         Ice Cream Shop                          Hotel      Halal Restaurant
# 6        Thai Restaurant                           Café    Seafood Restaurant
# 7         Ice Cream Shop                          Hotel      Halal Restaurant
# 8                  Hotel               Halal Restaurant            Food Truck
# 9            Flea Market                   Dessert Shop    Dim Sum Restaurant
# 10                Bakery                    Flower Shop                 Diner
# 11        Ice Cream Shop                          Hotel      Halal Restaurant
# 12             Reservoir           Fast Food Restaurant          Dessert Shop
# 13  Fast Food Restaurant  Vegetarian / Vegan Restaurant    Dim Sum Restaurant
# 14      Department Store                   Dessert Shop    Dim Sum Restaurant
# 15        Ice Cream Shop                          Hotel      Halal Restaurant
# 16          Dessert Shop             Dim Sum Restaurant                 Diner
# 17          Dessert Shop             Dim Sum Restaurant                 Diner
# 18     Convenience Store           Fast Food Restaurant          Dessert Shop
# 19                 Hotel               Halal Restaurant            Food Truck
# 20        Ice Cream Shop                          Hotel      Halal Restaurant
# 21      Department Store                 Ice Cream Shop                 Hotel
# 22        Ice Cream Shop                          Hotel      Halal Restaurant
# 23                 Diner  Vegetarian / Vegan Restaurant           Flea Market
# 24          Dessert Shop             Dim Sum Restaurant                 Diner
# 25        Ice Cream Shop                          Hotel      Halal Restaurant
# 26        Ice Cream Shop                          Hotel      Halal Restaurant
# 27        Ice Cream Shop                          Hotel      Halal Restaurant
# 28     Electronics Store  Vegetarian / Vegan Restaurant           Flower Shop
# 29          Dessert Shop             Dim Sum Restaurant                 Diner
# 30   Japanese Restaurant                 Ice Cream Shop                 Hotel
# 31    Dim Sum Restaurant                          Diner     Electronics Store
# 32        Ice Cream Shop                          Hotel      Halal Restaurant
# 33        Ice Cream Shop                          Hotel      Halal Restaurant
# 34        Ice Cream Shop                          Hotel      Halal Restaurant
# 35        Ice Cream Shop                          Hotel      Halal Restaurant
# 36                 Hotel               Halal Restaurant            Food Truck
#
#    7th Most Common Venue 8th Most Common Venue 9th Most Common Venue  \
# 0                   Food                  Café           Flea Market
# 1      Electronics Store  Fast Food Restaurant           Flea Market
# 2      Electronics Store  Fast Food Restaurant           Flea Market
# 3      Electronics Store  Fast Food Restaurant           Flea Market
# 4      Electronics Store  Fast Food Restaurant           Flower Shop
# 5             Food Truck     Food & Drink Shop                  Food
# 6               Tea Room                   Pub    Chinese Restaurant
# 7             Food Truck     Food & Drink Shop                  Food
# 8      Food & Drink Shop                  Food           Flower Shop
# 9                  Diner     Electronics Store  Fast Food Restaurant
# 10     Electronics Store  Fast Food Restaurant           Flea Market
# 11            Food Truck     Food & Drink Shop                  Food
# 12    Dim Sum Restaurant                 Diner     Electronics Store
# 13                 Diner     Electronics Store           Flea Market
# 14                 Diner     Electronics Store  Fast Food Restaurant
# 15            Food Truck     Food & Drink Shop                  Food
# 16     Electronics Store  Fast Food Restaurant           Flea Market
# 17     Electronics Store  Fast Food Restaurant           Flower Shop
# 18    Dim Sum Restaurant                 Diner     Electronics Store
# 19     Food & Drink Shop                  Food           Flower Shop
# 20            Food Truck     Food & Drink Shop                  Food
# 21      Halal Restaurant            Food Truck     Food & Drink Shop
# 22            Food Truck     Food & Drink Shop                  Food
# 23          Dessert Shop    Dim Sum Restaurant     Electronics Store
# 24     Electronics Store  Fast Food Restaurant           Flea Market
# 25            Food Truck     Food & Drink Shop                  Food
# 26            Food Truck     Food & Drink Shop                  Food
# 27            Food Truck     Food & Drink Shop                  Food
# 28                 Diner  Fast Food Restaurant           Flea Market
# 29     Electronics Store  Fast Food Restaurant           Flea Market
# 30      Halal Restaurant            Food Truck     Food & Drink Shop
# 31  Fast Food Restaurant           Flea Market           Flower Shop
# 32            Food Truck     Food & Drink Shop                  Food
# 33            Food Truck     Food & Drink Shop                  Food
# 34            Food Truck     Food & Drink Shop                  Food
# 35            Food Truck     Food & Drink Shop                  Food
# 36     Food & Drink Shop                  Food           Flower Shop
#
#            10th Most Common Venue
# 0              Dim Sum Restaurant
# 1                            Food
# 2                            Food
# 3                            Food
# 4               Convenience Store
# 5                     Flower Shop
# 6                     Coffee Shop
# 7                     Flower Shop
# 8                     Flea Market
# 9   Vegetarian / Vegan Restaurant
# 10              Food & Drink Shop
# 11                    Flower Shop
# 12                    Flea Market
# 13                           Food
# 14  Vegetarian / Vegan Restaurant
# 15                    Flower Shop
# 16                           Food
# 17              Convenience Store
# 18                    Flower Shop
# 19                    Flea Market
# 20                    Flower Shop
# 21                    Flower Shop
# 22                    Flower Shop
# 23           Fast Food Restaurant
# 24                           Food
# 25                    Flower Shop
# 26                    Flower Shop
# 27                    Flower Shop
# 28                           Food
# 29                           Food
# 30                    Flea Market
# 31                           Food
# 32                    Flower Shop
# 33                    Flower Shop
# 34                    Flower Shop
# 35                    Flower Shop
# 36                    Flea Market

# %% [markdown]
# ### 5. Cluster types of sub-distritcts into 6 types by K-means clustering

# %%
# set number of clusters
kclusters = 6

th_grouped_clustering = th_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(th_grouped_clustering) 
# add clustering labels
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

th_merged = s_province

neighborhoods_venues_sorted.rename(columns = {'Neighborhood': 'TAMBON'}, inplace = True)
# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood

th_merged = th_merged.join(neighborhoods_venues_sorted.set_index('TAMBON'), on='TAMBON')
#th_merged = pd.merge(th_merged, )
#df2 = pd.merge(df,neighborhoods_venues_sorted, how='inner', on = '')

th_merged # check the last columns!
# Out:
#       TA_ID            TAMBON  AM_ID              AMPHOE     Province  \
# 0    900803        Choeng Sae   9008          Krasae Sin     Songkhla
# 1    901107  Khlong U Ta Phao   9011             Hat Yai     Songkhla
# 2    900703           Takhria   9007               Ranot     Songkhla
# 3    900705           Ban Mai   9007               Ranot     Songkhla
# 4    900106             Ko Yo   9001     Muaeng Songkhla     Songkhla
# ..      ...               ...    ...                 ...          ...
# 198  930109           Lam Pam   9301  Mueang Phatthalung  Phatthalung
# 199  930203   Khlong Cha Loem   9302             Kong Ra  Phatthalung
# 200  930604            Ko Mak   9306          Pak Phayun  Phatthalung
# 201  930402             Tanot   9304               Tamot  Phatthalung
# 202  930803        Nong Thong   9308              Pa Bon  Phatthalung
#
#      Latitude  Longitude  Cluster Labels      1st Most Common Venue  \
# 0       7.561    100.356             NaN                        NaN
# 1       7.045    100.446             1.0  Middle Eastern Restaurant
# 2       7.789    100.269             NaN                        NaN
# 3       7.780    100.288             NaN                        NaN
# 4       7.163    100.542             0.0         Seafood Restaurant
# ..        ...        ...             ...                        ...
# 198     7.648    100.188             NaN                        NaN
# 199     7.349     99.958             NaN                        NaN
# 200     7.435    100.329             NaN                        NaN
# 201     7.278    100.007             NaN                        NaN
# 202     7.162    100.008             NaN                        NaN
#
#              2nd Most Common Venue 3rd Most Common Venue  \
# 0                              NaN                   NaN
# 1    Vegetarian / Vegan Restaurant      Department Store
# 2                              NaN                   NaN
# 3                              NaN                   NaN
# 4    Vegetarian / Vegan Restaurant           Flea Market
# ..                             ...                   ...
# 198                            NaN                   NaN
# 199                            NaN                   NaN
# 200                            NaN                   NaN
# 201                            NaN                   NaN
# 202                            NaN                   NaN
#
#     4th Most Common Venue 5th Most Common Venue 6th Most Common Venue  \
# 0                     NaN                   NaN                   NaN
# 1          Ice Cream Shop                 Hotel      Halal Restaurant
# 2                     NaN                   NaN                   NaN
# 3                     NaN                   NaN                   NaN
# 4            Dessert Shop    Dim Sum Restaurant                 Diner
# ..                    ...                   ...                   ...
# 198                   NaN                   NaN                   NaN
# 199                   NaN                   NaN                   NaN
# 200                   NaN                   NaN                   NaN
# 201                   NaN                   NaN                   NaN
# 202                   NaN                   NaN                   NaN
#
#     7th Most Common Venue 8th Most Common Venue 9th Most Common Venue  \
# 0                     NaN                   NaN                   NaN
# 1              Food Truck     Food & Drink Shop                  Food
# 2                     NaN                   NaN                   NaN
# 3                     NaN                   NaN                   NaN
# 4       Electronics Store  Fast Food Restaurant           Flower Shop
# ..                    ...                   ...                   ...
# 198                   NaN                   NaN                   NaN
# 199                   NaN                   NaN                   NaN
# 200                   NaN                   NaN                   NaN
# 201                   NaN                   NaN                   NaN
# 202                   NaN                   NaN                   NaN
#
#     10th Most Common Venue
# 0                      NaN
# 1              Flower Shop
# 2                      NaN
# 3                      NaN
# 4        Convenience Store
# ..                     ...
# 198                    NaN
# 199                    NaN
# 200                    NaN
# 201                    NaN
# 202                    NaN
#
# [203 rows x 18 columns]

# %%
th_merged.dropna(subset = ['Cluster Labels'], axis = 0, inplace = True)

# %% [markdown]
# ### 6. Plots sub-districts with cluster indication on map

# %%
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=7)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(th_merged['Latitude'], th_merged['Longitude'], th_merged['Province'], th_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    clu = int(cluster)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[clu-1],
        fill=True,
        fill_color=rainbow[clu-1],
        fill_opacity=0.7).add_to(map_clusters)
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# The shown spots in map are the clustered sub-district. According to the map above, the cluster also filter sub-districts that have very few venue. It can be illustrated that the shown spots are the least optimum point to locate the new power plant since they have a lots of social communities neaby.

# %%
#th_merged.to_csv("Songkhla_th_merged.csv", index = False)

# %%
map_all = folium.Map(location=[latitude, longitude], zoom_start=9)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]
rainbow2 = ['#ff0000', '#ff6200', '#f74d7d', '#ff9a2e', '#cb2eff', '#fffc2e']

# add markers to the map
markers_colors = []
for lat, lng, tambon in zip(s_province['Latitude'], s_province['Longitude'], s_province['TAMBON']):
    label = '{}'.format(tambon)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='#0090b8',
        fill=True,
        fill_color='#0090b8',
        fill_opacity=0.7,
        parse_html=False).add_to(map_all)  

for lat, lon, poi, cluster in zip(th_merged['Latitude'], th_merged['Longitude'], th_merged['Province'], th_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    clu = int(cluster)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow2[clu-1],
        fill=True,
        fill_color=rainbow2[clu-1],
        fill_opacity=0.7).add_to(map_all)

    
map_all
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### 7. Calculate the optimum sub-districts that locates far away from community

# %% [markdown]
# #### 7.1 Calculate distance between sub-districts by latitude and longitude coordinates

# %%
from math import sin, cos, sqrt, atan2, radians

def get_distance(Lat1, Lon1, Lat2, Lon2):
    R = 6373.0

    lat1 = radians(Lat1)
    lon1 = radians(Lon1)
    lat2 = radians(Lat2)
    lon2 = radians(Lon2)

    dlon = lon2 - lon1
    dlat = lat2 - lat1

    a = sin(dlat / 2)**2 + cos(lat1) * cos(lat2) * sin(dlon / 2)**2
    c = 2 * atan2(sqrt(a), sqrt(1 - a))

    distance = R * c
    
    return(distance)

test = get_distance(52.2296756, 21.0122287, 52.406374, 16.9251681)

# %% [markdown]
# #### 7.2 Find the optimum sub-districts that locates far away from community

# %% [markdown]
# The distance in this study is 15 kilometers.

# %%
th_dis = s_province
th_dis = th_dis.set_index('TAMBON', inplace = False)

th_dis['dropp'] = int(0)

for lats, lngs, tbs in zip(s_province['Latitude'], s_province['Longitude'], s_province['TAMBON']):
    for i, j, k in zip(th_merged['Latitude'], th_merged['Longitude'], th_merged['TAMBON']):
        dis = get_distance(lats, lngs, i, j)
        if (dis <= 15): 
            #th_dis = th_dis.drop(tbs) 
            th_dis.loc[tbs, 'dropp'] = 1
            break
        else: continue 
        break
th_dis = th_dis[th_dis.dropp != 1]
#th_dis2 = s_province[th_dis.drop]
th_dis2 = th_dis.dropna(subset= ['TA_ID'], axis = 0, inplace = True)

# %%
map_opt = folium.Map(location = [latitude, longitude], zoom_start = 9)
for lat, lng, tambon in zip(th_dis['Latitude'], th_dis['Longitude'], th_dis.index):
    label = '{}'.format(tambon)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='green',
        fill=True,
        fill_color='green',
        fill_opacity=0.7,
        parse_html=False).add_to(map_opt)  
    
map_opt
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### 8. Plots all the sub-districts in area with the information from lowest to highest optimum location of new power plants.

# %%
map_final = folium.Map(location=[latitude, longitude], zoom_start=9)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]
rainbow2 = ['#ff0000', '#ff6200', '#f74d7d', '#ff9a2e', '#cb2eff', '#FF78BC']

# add markers to the map
markers_colors = []
for lat, lng, tambon in zip(s_province['Latitude'], s_province['Longitude'], s_province['TAMBON']):
    label = '{}'.format(tambon)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='#A28901',
        fill=True,
        fill_color='#A28901',
        fill_opacity=0.7,
        parse_html=False).add_to(map_final)  

for lat, lon, poi, cluster in zip(th_merged['Latitude'], th_merged['Longitude'], th_merged['Province'], th_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    clu = int(cluster)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow2[clu-1],
        fill=True,
        fill_color=rainbow2[clu-1],
        fill_opacity=0.7).add_to(map_final)
    
for lat, lng, tambon in zip(th_dis['Latitude'], th_dis['Longitude'], th_dis.index):
    label = '{}'.format(tambon)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='#1FDC0C',
        fill=True,
        fill_color='#1FDC0C',
        fill_opacity=0.7,
        parse_html=False).add_to(map_final)  


map_final
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Results and Discussion <a name="results"></a>

# %% [markdown]
# From the map above, green spots are the most optimum locations to locate the new power plant according to the concern of impacts towards neaby community. They locates at least 15 kilometers away from communities. The brown spots are the sub-districts that do not have high density community but locates close to the dense populace. The red-toned spots are the least optimum locations due to the conentrated community.

# %% [markdown]
# In order to locate site of power plant, however, other considerations are needed for instance, transmission systems, distribution of fuel, etc. The final decision selecting locations from this study alone can not be made.
# **Therefore the plots of this study can be implements as the one factor in the trade-off for seleting locations. If there is a necessity to locate power plant in brown or red-toned area, the result from this study can help to assess impact of power plant towards difference types of clustered community.**

# %% [markdown]
# ## Conclusion <a name="conclusion"></a>

# %% [markdown]
# This study sorts and illustrates the order of optimal location of power plant with the consideration of impact towards nearby locals. The area of study is Songkhla and Patthalung province which locates in the southern of Thailand. The methodogies implemented are including; collection of latitude and longitude coordinate, plot locations on map by Folium, collection of venues information by Foursqure, cluster venues in are by K-means cluster and calculate the distance by latitude and longitude coordinate by 'haversine' formular. The results illustrates the order of optimal location power plant in the area. This study can be implemented to help to assess impact of power plant towards difference types of clustered community.
